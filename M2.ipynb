# %% [markdown]
# ## DATA VISUALIZATION AND DATA ANALYSIS

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('AIR_DATA.csv')
del df['StationId']
del df['Datetime']
df.head()
# Out:
# C:\Users\Rohith\AppData\Local\Temp\ipykernel_17392\3982892396.py:1: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('AIR_DATA.csv')
#    PM2.5    PM10    NO    NO2    NOx    NH3   CO    SO2      O3  Benzene  \
# 0  60.50   98.00  2.35  30.80  18.25   8.50  0.1  11.85  126.40      0.1
# 1  65.50  111.25  2.70  24.20  15.07   9.77  0.1  13.17  117.12      0.1
# 2  80.00  132.00  2.10  25.18  15.15  12.02  0.1  12.08   98.98      0.2
# 3  81.50  133.25  1.95  16.25  10.23  11.58  0.1  10.47  112.20      0.2
# 4  75.25  116.00  1.43  17.48  10.43  12.03  0.1   9.12  106.35      0.2
#
#    Toluene  Xylene  AQI AQI_Bucket
# 0     6.10    0.10  NaN        NaN
# 1     6.25    0.15  NaN        NaN
# 2     5.98    0.18  NaN        NaN
# 3     6.72    0.10  NaN        NaN
# 4     5.75    0.08  NaN        NaN

# %%
df.columns
# Out:
# Index(['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3',
#        'Benzene', 'Toluene', 'Xylene', 'AQI', 'AQI_Bucket'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

var = ['AQI_Bucket']
  
for i in var:
    df[i] = le.fit_transform(df[i]).astype(int)

# %%
plt.figure(figsize=(12,7))
sns.countplot(x='AQI_Bucket',data=df)
# Out:
# <Axes: xlabel='AQI_Bucket', ylabel='count'>

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
plt.hist(df['PM2.5'],color='red')

plt.subplot(1,2,2)
plt.hist(df['PM10'],color='blue')
# Out:
# (array([632828., 459038., 188874.,  92759.,  46666.,  23249.,  12491.,
#           6807.,   4071.,   3048.]),
#  array([1.00000e-02, 1.00009e+02, 2.00008e+02, 3.00007e+02, 4.00006e+02,
#         5.00005e+02, 6.00004e+02, 7.00003e+02, 8.00002e+02, 9.00001e+02,
#         1.00000e+03]),
#  <BarContainer object of 10 artists>)

# %%
df.hist(figsize=(15,55),layout=(15,4), color='green')
plt.show()

# %%
sns.lineplot(df['NO2'], color='brown') # scatter, plot, triplot, stackplot
# Out:
# <Axes: ylabel='NO2'>

# %%
sns.violinplot(df['NOx'], color='purple')
# Out:
# <Axes: ylabel='NOx'>

# %%
df['NH3'].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
sns.displot(df['CO'], color='purple') 
# barplot, boxenplot, boxplot, countplot, displot, distplot, ecdfplot, histplot, kdeplot, pointplot, violinplot, stripplot

# %%
sns.displot(df['SO2'], color='coral') # residplot, scatterplot

# %%
fig, ax = plt.subplots(figsize=(20,15))
sns.heatmap(df.corr(),annot = True, fmt='0.2%',cmap = 'autumn',ax=ax)
# Out:
# <Axes: >

# %%
def plot(df, variable):
    dataframe_pie = df[variable].value_counts()
    ax = dataframe_pie.plot.pie(figsize=(9,9), autopct='%1.2f%%', fontsize = 10)
    ax.set_title(variable + ' \n', fontsize = 10)
    return np.round(dataframe_pie/df.shape[0]*100,2)

plot(df, 'AQI_Bucket')
# Out:
# AQI_Bucket
# 1    26.07
# 6    22.02
# 3    20.48
# 5    11.63
# 2     9.27
# 0     5.88
# 4     4.65
# Name: count, dtype: float64
